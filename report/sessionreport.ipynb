# %%
# %load_ext autoreload
# %autoreload 2
if "PKG" not in globals():
  import importlib, os, sys, pathlib # https://stackoverflow.com/a/50395128/11996983
  PKG = %pwd
  PKG = pathlib.Path(PKG)
  __package__ = f"{PKG.name}"
  MODULE_PATH = f"{PKG}{pathlib.os.path.sep}__init__.py"
  MODULE_NAME = f"{PKG.name}"
  # print(MODULE_NAME, MODULE_PATH)
  spec = importlib.util.spec_from_file_location(MODULE_NAME, MODULE_PATH)
  module = importlib.util.module_from_spec(spec)
  sys.modules[spec.name] = module
  spec.loader.exec_module(module)

# %%
def test():
  import matplotlib.pyplot as plt
  from . import sessionreport
  #SESSION_NAME="Dummy Subject_Mouse2AFC_Feb04_2021_Session14.mat"
  # SESSION_NAME="vgat2.5_Mouse2AFC_Dec22_2020_Session1.mat"
  SESSION_NAME="WF11_Mouse2AFC_Aug21_2022_Session1.mat"
  df = sessionreport.makeReport(SESSION_NAME, show_fig=True, save_fig=False)
  # if __name__ == "__main__":
  #   sessionreport.regenerateAllSessionReport()
  # plt.show()
  return df
df = test()
# Out:
# matlab_file: C:\BpodUser\Data\WF11\Mouse2AFC\Session Data\WF11_Mouse2AFC_Aug21_2022_Session1.mat
# Max Trials: 268
# Processing C:\BpodUser\Data\WF11\Mouse2AFC\Session Data\WF11_Mouse2AFC_Aug21_2022_Session1.mat
# Assigning protocol: Mouse2AFC
#
# Session df length: 268
# Skipping opto config psych with less than 5
# α: 0.39730215575150235 - β: 0.7414321962379216 - λ1: 0.1285178211617916 - λ2: 0.10863862888974599
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# df.ST
# df["DiffST"] = df.calcStimulusTime - df.ST - df.calcMovementTime
# df[["ST", "calcStimulusTime", "calcMovementTime", "DiffST"]]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 232    0
# 233    0
# 234    0
# 235    0
# 236    0
# Name: GUI_FeedbackDelayMin, Length: 237, dtype: uint8
